# %%
# Imports
import os
import numpy as np
import matplotlib.pyplot as plt
import dxchange
import tifffile
import pandas as pd

os.chdir("/dtu/3d-imaging-center/courses/02509/groups/members/s194333/HPC3D_project/code/")
import functions as fnc

# %%
# load the full data, bin_data and mask for the three stones (for the the Island ny stone we also load the downsampled data)

folder_path = '/dtu/3d-imaging-center/courses/02509/groups/group01'

stone = 'island_ny'
file_name = 'lavasten_Island_ny_LFOV-80kV-LE2-1.8s-21.8micro_recon.txm'
absolute_path = os.path.join(folder_path, stone, file_name)
all_data_ny = dxchange.reader.read_txm(absolute_path)

# the new island ny stone is downsampled by a factor of 2 in each dimension
file_name = 'bin_data_downsampled.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
bin_data_ny = tifffile.imread(absolute_path)
bin_data_ny = bin_data_ny.astype(np.uint8)

file_name = 'mask_downsampled.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
mask_ny = tifffile.imread(absolute_path)
mask_ny = mask_ny.astype(np.uint8)

file_name = 'bin_data.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
bin_data_ny_org = tifffile.imread(absolute_path)

file_name = 'mask.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
mask_ny_org = tifffile.imread(absolute_path)

stone = 'island_gammel'
file_name = 'lavasten_Island_gammel_LFOV-80kV-LE5-4s-45.3micro_recon.txm'
absolute_path = os.path.join(folder_path, stone, file_name)
all_data_gl = dxchange.reader.read_txm(absolute_path)

file_name = 'bin_data.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
bin_data_gl = tifffile.imread(absolute_path)

file_name = 'mask.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
mask_gl = tifffile.imread(absolute_path)

stone = 'madagascar'
file_name = 'lavasten_Madagascar_LFOV-80kV-LE2-1.5s-42micro_recon.txm'
absolute_path = os.path.join(folder_path, stone, file_name)
all_data_ma = dxchange.reader.read_txm(absolute_path)

stone = 'madagascar'
file_name = 'bin_data.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
bin_data_ma = tifffile.imread(absolute_path)

file_name = 'mask.tiff'
absolute_path = os.path.join(folder_path, stone, file_name)
mask_ma = tifffile.imread(absolute_path)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[24], line 8
#       6 file_name = 'lavasten_Island_ny_LFOV-80kV-LE2-1.8s-21.8micro_recon.txm'
#       7 absolute_path = os.path.join(folder_path, stone, file_name)
# ----> 8 all_data_ny = dxchange.reader.read_txm(absolute_path)
#      10 # the new island ny stone is downsampled by a factor of 2 in each dimension
#      11 file_name = 'bin_data_downsampled.tiff'
#
# File /dtu/3d-imaging-center/courses/conda/miniconda3/envs/env-02509/lib/python3.12/site-packages/dxchange/reader.py:489, in read_txm(file_name, slice_range)
#     466 def read_txm(file_name, slice_range=None):
#     467     """
#     468     Read data from a .txm file, the reconstruction file output
#     469     by Zeiss software.
#    (...)
#     486         Dictionary of metadata.
#     487     """
# --> 489     return read_txrm(file_name, slice_range)
#
# File /dtu/3d-imaging-center/courses/conda/miniconda3/envs/env-02509/lib/python3.12/site-packages/dxchange/reader.py:434, in read_txrm(file_name, slice_range)
#     430     return False
#     432 metadata = read_ole_metadata(ole)
# --> 434 array_of_images = np.empty(
#     435     _shape_after_slice(
#     436         (
#     437             metadata["number_of_images"],
#     438             metadata["image_height"],
#     439             metadata["image_width"],
#     440         ),
#     441         slice_range
#     442     ),
#     443     dtype=_get_ole_data_type(metadata)
#     444 )
#     446 if slice_range is None:
#     447     slice_range = (slice(None), slice(None), slice(None))
#
# MemoryError: Unable to allocate 1.95 GiB for an array with shape (1018, 1024, 1004) and data type uint16

# %%
# get the data and the inspect the metadata for the downsampled new Island stone
pixel_size_ny = all_data_ny[1]['pixel_size']*2
print(f'Pixel size: {pixel_size_ny} um')
img_shape_ny = bin_data_ny.shape
print(f'Image shape: {img_shape_ny}')
img_shape_array = np.array(img_shape_ny)
total_size_ny = img_shape_array * pixel_size_ny
total_size__mm_ny = total_size_ny/1000
print(f'Total size: {total_size__mm_ny} mm')
pixel_size_mm_ny = pixel_size_ny/1000
print(f'Pixel size in mm: {pixel_size_mm_ny}')
pixels_per_mm_ny = 1/pixel_size_mm_ny
print(f'Pixels per mm: {pixels_per_mm_ny}')
print(pixels_per_mm_ny)
# Out:
# Pixel size: 43.64527130126953 um
# Image shape: (509, 512, 502)
# Total size: [22.21544309 22.34637891 21.90992619] mm
# Pixel size in mm: 0.04364527130126953
# Pixels per mm: 22.911989550879767
# 22.911989550879767

# %%
# get the data and the inspect the metadata for the original new Island stone
pixel_size_ny_org = all_data_ny[1]['pixel_size']
print(f'Pixel size: {pixel_size_ny_org} um')
img_shape_ny_org = bin_data_ny_org.shape
print(f'Image shape: {img_shape_ny_org}')
img_shape_array = np.array(img_shape_ny_org)
total_size_ny_org = img_shape_array * pixel_size_ny_org
total_size__mm_ny_org = total_size_ny_org/1000
print(f'Total size: {total_size__mm_ny_org} mm')
pixel_size_mm_ny_org = pixel_size_ny_org/1000
print(f'Pixel size in mm: {pixel_size_mm_ny_org}')
pixels_per_mm_ny_org = 1/pixel_size_mm_ny_org
print(f'Pixels per mm: {pixels_per_mm_ny_org}')
# Out:
# Pixel size: 21.822635650634766 um
# Image shape: (1018, 1024, 1004)
# Total size: [22.21544309 22.34637891 21.90992619] mm
# Pixel size in mm: 0.021822635650634765
# Pixels per mm: 45.823979101759534

# %%
# get the data and the inspect the metadata for the old Island stone
pixel_size_gl = all_data_gl[1]['pixel_size']
print(f'Pixel size: {pixel_size_gl} um')
img_shape_gl = bin_data_gl.shape
print(f'Image shape: {img_shape_gl}')
img_shape_array = np.array(img_shape_gl)
total_size_gl = img_shape_array * pixel_size_gl
total_size__mm_gl = total_size_gl/1000
print(f'Total size: {total_size__mm_gl} mm')
pixel_size_mm_gl = pixel_size_gl/1000
print(f'Pixel size in mm: {pixel_size_mm_gl}')
pixels_per_mm_gl = 1/pixel_size_mm_gl
print(f'Pixels per mm: {pixels_per_mm_gl}')
# Out:
# Pixel size: 45.34814453125 um
# Image shape: (1017, 1024, 1004)
# Total size: [46.11906299 46.4365     45.52953711] mm
# Pixel size in mm: 0.04534814453125
# Pixels per mm: 22.051618877391707

# %%
# get the data and the inspect the metadata for the Madagascar stone
pixel_size_ma = all_data_ma[1]['pixel_size']
print(f'Pixel size: {pixel_size_ma} um')
img_shape_ma = bin_data_ma.shape
print(f'Image shape: {img_shape_ma}')
img_shape_array = np.array(img_shape_ma)
total_size_ma = img_shape_array * pixel_size_ma
total_size__mm_ma = total_size_ma/1000
print(f'Total size: {total_size__mm_ma} mm')
pixel_size_mm_ma = pixel_size_ma/1000
print(f'Pixel size in mm: {pixel_size_mm_ma}')
pixels_per_mm_ma = 1/pixel_size_mm_ma
print(f'Pixels per mm: {pixels_per_mm_ma}')
# Out:
# Pixel size: 41.99748992919922 um
# Image shape: (1018, 1024, 1004)
# Total size: [42.75344475 43.00542969 42.16547989] mm
# Pixel size in mm: 0.041997489929199217
# Pixels per mm: 23.810946837199882

# %%
# choose the sample size in mm
sample_size = 4

# extract the samples
grid_samples_ny = fnc.extract_samples(mask=mask_ny,
                               pixels_per_mm=pixels_per_mm_ny,
                               mm_per_grid=sample_size,
                               discard_threshold=0.33)


print(f'Number of samples downsampled new Island stone: {len(grid_samples_ny)}')

grid_samples_ny_org = fnc.extract_samples(mask=mask_ny_org,
                               pixels_per_mm=pixels_per_mm_ny_org,
                               mm_per_grid=sample_size,
                               discard_threshold=0.33)


print(f'Number of samples original new Island stone: {len(grid_samples_ny_org)}')

grid_samples_gl = fnc.extract_samples(mask=mask_gl,
                                 pixels_per_mm=pixels_per_mm_gl,
                                 mm_per_grid=sample_size,
                                 discard_threshold=0.33)

print(f'Number of samples old Island stone: {len(grid_samples_gl)}')

grid_samples_ma = fnc.extract_samples(mask=mask_ma,
                                    pixels_per_mm=pixels_per_mm_ma,
                                    mm_per_grid=sample_size,
                                    discard_threshold=0.33)

print(f'Number of samples Madagascar stone: {len(grid_samples_ma)}')
# Out:
# Number of samples downsampled new Island stone: 21
# Number of samples original new Island stone: 21
# Number of samples old Island stone: 196
# Number of samples Madagascar stone: 240

# %%
# Get the statistics for each sample in the downsampled new Island stone
statistics_ny = []
for i, grid_dict in enumerate(grid_samples_ny):
    print(f'Processing sample {i}/{len(grid_samples_ny)}')
    bin_sample = fnc.apply_grid(volume=bin_data_ny, grid_dict=grid_dict)
    mask_sample = fnc.apply_grid(volume=mask_ny, grid_dict=grid_dict)
    stats = fnc.get_statistics(bin_sample, mask_sample, pixel_size_mm_ny)
    statistics_ny.append(stats)
# Out:
# Processing sample 0/21
# Processing sample 1/21
# Processing sample 2/21
# Processing sample 3/21
# Processing sample 4/21
# Processing sample 5/21
# Processing sample 6/21
# Processing sample 7/21
# Processing sample 8/21
# Processing sample 9/21
# Processing sample 10/21
# Processing sample 11/21
# Processing sample 12/21
# Processing sample 13/21
# Processing sample 14/21
# Processing sample 15/21
# Processing sample 16/21
# Processing sample 17/21
# Processing sample 18/21
# Processing sample 19/21
# Processing sample 20/21

# %%
# Get the statistics for each sample in the original new Island stone
statistics_ny_org = []
for i, grid_dict in enumerate(grid_samples_ny_org):
    print(f'Processing sample {i}/{len(grid_samples_ny_org)}')
    bin_sample = fnc.apply_grid(volume=bin_data_ny_org, grid_dict=grid_dict)
    mask_sample = fnc.apply_grid(volume=mask_ny_org, grid_dict=grid_dict)
    stats = fnc.get_statistics(bin_sample, mask_sample, pixel_size_mm_ny_org)
    statistics_ny_org.append(stats)
# Out:
# Processing sample 0/21
# Processing sample 1/21
# Processing sample 2/21
# Processing sample 3/21
# Processing sample 4/21
# Processing sample 5/21
# Processing sample 6/21
# Processing sample 7/21
# Processing sample 8/21
# Processing sample 9/21
# Processing sample 10/21
# Processing sample 11/21
# Processing sample 12/21
# Processing sample 13/21
# Processing sample 14/21
# Processing sample 15/21
# Processing sample 16/21
# Processing sample 17/21
# Processing sample 18/21
# Processing sample 19/21
# Processing sample 20/21

# %%
# Get the statistics for each sample in the old Island stone
statistics_gl = []
for i, grid_dict in enumerate(grid_samples_gl):
    print(f'Processing sample {i}/{len(grid_samples_gl)}')
    bin_sample = fnc.apply_grid(volume=bin_data_gl, grid_dict=grid_dict)
    mask_sample = fnc.apply_grid(volume=mask_gl, grid_dict=grid_dict)
    stats = fnc.get_statistics(bin_sample, mask_sample, pixel_size_mm_gl)
    statistics_gl.append(stats)
# Out:
# Processing sample 0/196
# Processing sample 1/196
# Processing sample 2/196
# Processing sample 3/196
# Processing sample 4/196
# Processing sample 5/196
# Processing sample 6/196
# Processing sample 7/196
# Processing sample 8/196
# Processing sample 9/196
# Processing sample 10/196
# Processing sample 11/196
# Processing sample 12/196
# Processing sample 13/196
# Processing sample 14/196
# Processing sample 15/196
# Processing sample 16/196
# Processing sample 17/196
# Processing sample 18/196
# Processing sample 19/196
# Processing sample 20/196
# Processing sample 21/196
# Processing sample 22/196
# Processing sample 23/196
# Processing sample 24/196
# Processing sample 25/196
# Processing sample 26/196
# Processing sample 27/196
# Processing sample 28/196
# Processing sample 29/196
# Processing sample 30/196
# Processing sample 31/196
# Processing sample 32/196
# Processing sample 33/196
# Processing sample 34/196
# Processing sample 35/196
# Processing sample 36/196
# Processing sample 37/196
# Processing sample 38/196
# Processing sample 39/196
# Processing sample 40/196
# Processing sample 41/196
# Processing sample 42/196
# Processing sample 43/196
# Processing sample 44/196
# Processing sample 45/196
# Processing sample 46/196
# Processing sample 47/196
# Processing sample 48/196
# Processing sample 49/196
# Processing sample 50/196
# Processing sample 51/196
# Processing sample 52/196
# Processing sample 53/196
# Processing sample 54/196
# Processing sample 55/196
# Processing sample 56/196
# Processing sample 57/196
# Processing sample 58/196
# Processing sample 59/196
# Processing sample 60/196
# Processing sample 61/196
# Processing sample 62/196
# Processing sample 63/196
# Processing sample 64/196
# Processing sample 65/196
# Processing sample 66/196
# Processing sample 67/196
# Processing sample 68/196
# Processing sample 69/196
# Processing sample 70/196
# Processing sample 71/196
# Processing sample 72/196
# Processing sample 73/196
# Processing sample 74/196
# Processing sample 75/196
# Processing sample 76/196
# Processing sample 77/196
# Processing sample 78/196
# Processing sample 79/196
# Processing sample 80/196
# Processing sample 81/196
# Processing sample 82/196
# Processing sample 83/196
# Processing sample 84/196
# Processing sample 85/196
# Processing sample 86/196
# Processing sample 87/196
# Processing sample 88/196
# Processing sample 89/196
# Processing sample 90/196
# Processing sample 91/196
# Processing sample 92/196
# Processing sample 93/196
# Processing sample 94/196
# Processing sample 95/196
# Processing sample 96/196
# Processing sample 97/196
# Processing sample 98/196
# Processing sample 99/196
# Processing sample 100/196
# Processing sample 101/196
# Processing sample 102/196
# Processing sample 103/196
# Processing sample 104/196
# Processing sample 105/196
# Processing sample 106/196
# Processing sample 107/196
# Processing sample 108/196
# Processing sample 109/196
# Processing sample 110/196
# Processing sample 111/196
# Processing sample 112/196
# Processing sample 113/196
# Processing sample 114/196
# Processing sample 115/196
# Processing sample 116/196
# Processing sample 117/196
# Processing sample 118/196
# Processing sample 119/196
# Processing sample 120/196
# Processing sample 121/196
# Processing sample 122/196
# Processing sample 123/196
# Processing sample 124/196
# Processing sample 125/196
# Processing sample 126/196
# Processing sample 127/196
# Processing sample 128/196
# Processing sample 129/196
# Processing sample 130/196
# Processing sample 131/196
# Processing sample 132/196
# Processing sample 133/196
# Processing sample 134/196
# Processing sample 135/196
# Processing sample 136/196
# Processing sample 137/196
# Processing sample 138/196
# Processing sample 139/196
# Processing sample 140/196
# Processing sample 141/196
# Processing sample 142/196
# Processing sample 143/196
# Processing sample 144/196
# Processing sample 145/196
# Processing sample 146/196
# Processing sample 147/196
# Processing sample 148/196
# Processing sample 149/196
# Processing sample 150/196
# Processing sample 151/196
# Processing sample 152/196
# Processing sample 153/196
# Processing sample 154/196
# Processing sample 155/196
# Processing sample 156/196
# Processing sample 157/196
# Processing sample 158/196
# Processing sample 159/196
# Processing sample 160/196
# Processing sample 161/196
# Processing sample 162/196
# Processing sample 163/196
# Processing sample 164/196
# Processing sample 165/196
# Processing sample 166/196
# Processing sample 167/196
# Processing sample 168/196
# Processing sample 169/196
# Processing sample 170/196
# Processing sample 171/196
# Processing sample 172/196
# Processing sample 173/196
# Processing sample 174/196
# Processing sample 175/196
# Processing sample 176/196
# Processing sample 177/196
# Processing sample 178/196
# Processing sample 179/196
# Processing sample 180/196
# Processing sample 181/196
# Processing sample 182/196
# Processing sample 183/196
# Processing sample 184/196
# Processing sample 185/196
# Processing sample 186/196
# Processing sample 187/196
# Processing sample 188/196
# Processing sample 189/196
# Processing sample 190/196
# Processing sample 191/196
# Processing sample 192/196
# Processing sample 193/196
# Processing sample 194/196
# Processing sample 195/196

# %%
# Get the statistics for each sample in the Madagascar stone
statistics_ma = []
for i, grid_dict in enumerate(grid_samples_ma):
    print(f'Processing sample {i}/{len(grid_samples_ma)}')
    bin_sample = fnc.apply_grid(volume=bin_data_ma, grid_dict=grid_dict)
    mask_sample = fnc.apply_grid(volume=mask_ma, grid_dict=grid_dict)
    stats = fnc.get_statistics(bin_sample, mask_sample, pixel_size_mm_ma)
    statistics_ma.append(stats)
# Out:
# Processing sample 0/240
# Processing sample 1/240
# Processing sample 2/240
# Processing sample 3/240
# Processing sample 4/240
# Processing sample 5/240
# Processing sample 6/240
# Processing sample 7/240
# Processing sample 8/240
# Processing sample 9/240
# Processing sample 10/240
# Processing sample 11/240
# Processing sample 12/240
# Processing sample 13/240
# Processing sample 14/240
# Processing sample 15/240
# Processing sample 16/240
# Processing sample 17/240
# Processing sample 18/240
# Processing sample 19/240
# Processing sample 20/240
# Processing sample 21/240
# Processing sample 22/240
# Processing sample 23/240
# Processing sample 24/240
# Processing sample 25/240
# Processing sample 26/240
# Processing sample 27/240
# Processing sample 28/240
# Processing sample 29/240
# Processing sample 30/240
# Processing sample 31/240
# Processing sample 32/240
# Processing sample 33/240
# Processing sample 34/240
# Processing sample 35/240
# Processing sample 36/240
# Processing sample 37/240
# Processing sample 38/240
# Processing sample 39/240
# Processing sample 40/240
# Processing sample 41/240
# Processing sample 42/240
# Processing sample 43/240
# Processing sample 44/240
# Processing sample 45/240
# Processing sample 46/240
# Processing sample 47/240
# Processing sample 48/240
# Processing sample 49/240
# Processing sample 50/240
# Processing sample 51/240
# Processing sample 52/240
# Processing sample 53/240
# Processing sample 54/240
# Processing sample 55/240
# Processing sample 56/240
# Processing sample 57/240
# Processing sample 58/240
# Processing sample 59/240
# Processing sample 60/240
# Processing sample 61/240
# Processing sample 62/240
# Processing sample 63/240
# Processing sample 64/240
# Processing sample 65/240
# Processing sample 66/240
# Processing sample 67/240
# Processing sample 68/240
# Processing sample 69/240
# Processing sample 70/240
# Processing sample 71/240
# Processing sample 72/240
# Processing sample 73/240
# Processing sample 74/240
# Processing sample 75/240
# Processing sample 76/240
# Processing sample 77/240
# Processing sample 78/240
# Processing sample 79/240
# Processing sample 80/240
# Processing sample 81/240
# Processing sample 82/240
# Processing sample 83/240
# Processing sample 84/240
# Processing sample 85/240
# Processing sample 86/240
# Processing sample 87/240
# Processing sample 88/240
# Processing sample 89/240
# Processing sample 90/240
# Processing sample 91/240
# Processing sample 92/240
# Processing sample 93/240
# Processing sample 94/240
# Processing sample 95/240
# Processing sample 96/240
# Processing sample 97/240
# Processing sample 98/240
# Processing sample 99/240
# Processing sample 100/240
# Processing sample 101/240
# Processing sample 102/240
# Processing sample 103/240
# Processing sample 104/240
# Processing sample 105/240
# Processing sample 106/240
# Processing sample 107/240
# Processing sample 108/240
# Processing sample 109/240
# Processing sample 110/240
# Processing sample 111/240
# Processing sample 112/240
# Processing sample 113/240
# Processing sample 114/240
# Processing sample 115/240
# Processing sample 116/240
# Processing sample 117/240
# Processing sample 118/240
# Processing sample 119/240
# Processing sample 120/240
# Processing sample 121/240
# Processing sample 122/240
# Processing sample 123/240
# Processing sample 124/240
# Processing sample 125/240
# Processing sample 126/240
# Processing sample 127/240
# Processing sample 128/240
# Processing sample 129/240
# Processing sample 130/240
# Processing sample 131/240
# Processing sample 132/240
# Processing sample 133/240
# Processing sample 134/240
# Processing sample 135/240
# Processing sample 136/240
# Processing sample 137/240
# Processing sample 138/240
# Processing sample 139/240
# Processing sample 140/240
# Processing sample 141/240
# Processing sample 142/240
# Processing sample 143/240
# Processing sample 144/240
# Processing sample 145/240
# Processing sample 146/240
# Processing sample 147/240
# Processing sample 148/240
# Processing sample 149/240
# Processing sample 150/240
# Processing sample 151/240
# Processing sample 152/240
# Processing sample 153/240
# Processing sample 154/240
# Processing sample 155/240
# Processing sample 156/240
# Processing sample 157/240
# Processing sample 158/240
# Processing sample 159/240
# Processing sample 160/240
# Processing sample 161/240
# Processing sample 162/240
# Processing sample 163/240
# Processing sample 164/240
# Processing sample 165/240
# Processing sample 166/240
# Processing sample 167/240
# Processing sample 168/240
# Processing sample 169/240
# Processing sample 170/240
# Processing sample 171/240
# Processing sample 172/240
# Processing sample 173/240
# Processing sample 174/240
# Processing sample 175/240
# Processing sample 176/240
# Processing sample 177/240
# Processing sample 178/240
# Processing sample 179/240
# Processing sample 180/240
# Processing sample 181/240
# Processing sample 182/240
# Processing sample 183/240
# Processing sample 184/240
# Processing sample 185/240
# Processing sample 186/240
# Processing sample 187/240
# Processing sample 188/240
# Processing sample 189/240
# Processing sample 190/240
# Processing sample 191/240
# Processing sample 192/240
# Processing sample 193/240
# Processing sample 194/240
# Processing sample 195/240
# Processing sample 196/240
# Processing sample 197/240
# Processing sample 198/240
# Processing sample 199/240
# Processing sample 200/240
# Processing sample 201/240
# Processing sample 202/240
# Processing sample 203/240
# Processing sample 204/240
# Processing sample 205/240
# Processing sample 206/240
# Processing sample 207/240
# Processing sample 208/240
# Processing sample 209/240
# Processing sample 210/240
# Processing sample 211/240
# Processing sample 212/240
# Processing sample 213/240
# Processing sample 214/240
# Processing sample 215/240
# Processing sample 216/240
# Processing sample 217/240
# Processing sample 218/240
# Processing sample 219/240
# Processing sample 220/240
# Processing sample 221/240
# Processing sample 222/240
# Processing sample 223/240
# Processing sample 224/240
# Processing sample 225/240
# Processing sample 226/240
# Processing sample 227/240
# Processing sample 228/240
# Processing sample 229/240
# Processing sample 230/240
# Processing sample 231/240
# Processing sample 232/240
# Processing sample 233/240
# Processing sample 234/240
# Processing sample 235/240
# Processing sample 236/240
# Processing sample 237/240
# Processing sample 238/240
# Processing sample 239/240

# %%
# save the statistics in lists

ratios_ny = [stat['ratio'] for stat in statistics_ny]
ratios_gl = [stat['ratio'] for stat in statistics_gl]
ratios_ma = [stat['ratio'] for stat in statistics_ma]

mean_thickness_stone_ny = [stat['mean_thickness_stone'] for stat in statistics_ny]
mean_thickness_stone_gl = [stat['mean_thickness_stone'] for stat in statistics_gl]
mean_thickness_stone_ma = [stat['mean_thickness_stone'] for stat in statistics_ma]

mean_thickness_bubbles_ny = [stat['mean_thickness_bubbles'] for stat in statistics_ny]
mean_thickness_bubbles_gl = [stat['mean_thickness_bubbles'] for stat in statistics_gl]
mean_thickness_bubbles_ma = [stat['mean_thickness_bubbles'] for stat in statistics_ma]

median_thickness_stone_ny = [stat['median_thickness_stone'] for stat in statistics_ny]
median_thickness_stone_gl = [stat['median_thickness_stone'] for stat in statistics_gl]
median_thickness_stone_ma = [stat['median_thickness_stone'] for stat in statistics_ma]

median_thickness_bubbles_ny = [stat['median_thickness_bubbles'] for stat in statistics_ny]
median_thickness_bubbles_gl = [stat['median_thickness_bubbles'] for stat in statistics_gl]
median_thickness_bubbles_ma = [stat['median_thickness_bubbles'] for stat in statistics_ma]

max_thickness_stone_ny = [stat['max_thickness_stone'] for stat in statistics_ny]
max_thickness_stone_gl = [stat['max_thickness_stone'] for stat in statistics_gl]
max_thickness_stone_ma = [stat['max_thickness_stone'] for stat in statistics_ma]

max_thickness_bubbles_ny = [stat['max_thickness_bubbles'] for stat in statistics_ny]
max_thickness_bubbles_gl = [stat['max_thickness_bubbles'] for stat in statistics_gl]
max_thickness_bubbles_ma = [stat['max_thickness_bubbles'] for stat in statistics_ma]

var_thickness_stone_ny = [stat['var_thickness_stone'] for stat in statistics_ny]
var_thickness_stone_gl = [stat['var_thickness_stone'] for stat in statistics_gl]
var_thickness_stone_ma = [stat['var_thickness_stone'] for stat in statistics_ma]

var_thickness_bubbles_ny = [stat['var_thickness_bubbles'] for stat in statistics_ny]
var_thickness_bubbles_gl = [stat['var_thickness_bubbles'] for stat in statistics_gl]
var_thickness_bubbles_ma = [stat['var_thickness_bubbles'] for stat in statistics_ma]

time_stone_ny = [stat['time_stone'] for stat in statistics_ny]
time_stone_ny_org = [stat['time_stone'] for stat in statistics_ny_org]
time_stone_gl = [stat['time_stone'] for stat in statistics_gl]
time_stone_ma = [stat['time_stone'] for stat in statistics_ma]

time_bubbles_ny = [stat['time_bubbles'] for stat in statistics_ny]
time_bubbles_ny_org = [stat['time_bubbles'] for stat in statistics_ny_org]
time_bubbles_gl = [stat['time_bubbles'] for stat in statistics_gl]
time_bubbles_ma = [stat['time_bubbles'] for stat in statistics_ma]

# %%
# Investigate the average time it takes to calculate the local thickness on the samples
print(f'Average time downsampled new Island stone: {np.mean(time_stone_ny)}')
print(f'Average time original new Island stone: {np.mean(time_stone_ny_org)}')
print(f'Average time old Island stone: {np.mean(time_stone_gl)}')
print(f'Average time Madagascar stone: {np.mean(time_stone_ma)}')

print(f'Average time downsampled new Island bubbles: {np.mean(time_bubbles_ny)}')
print(f'Average time original new Island bubbles: {np.mean(time_bubbles_ny_org)}')
print(f'Average time old Island bubbles: {np.mean(time_bubbles_gl)}')
print(f'Average time Madagascar bubbles: {np.mean(time_bubbles_ma)}')
# Out:
# Average time downsampled new Island stone: 0.6382615906851632
# Average time original new Island stone: 16.753327619461786
# Average time old Island stone: 0.5911188685164159
# Average time Madagascar stone: 0.5022349178791046
# Average time downsampled new Island bubbles: 0.5884951409839448
# Average time original new Island bubbles: 16.971735466094245
# Average time old Island bubbles: 0.6028482816657241
# Average time Madagascar bubbles: 0.6168992141882579

# %%
# Visualize boxplots of the statistics
fig, ax = plt.subplots(1, 9, figsize=(30, 5))
ax[0].boxplot([ratios_ny, ratios_gl, ratios_ma])
ax[0].set_title('Ratios')
ax[0].set_xticklabels(['ny', 'gl', 'ma'])

ax[1].boxplot([mean_thickness_stone_ny, mean_thickness_stone_gl, mean_thickness_stone_ma])
ax[1].set_title('Mean thickness stone')
ax[1].set_xticklabels(['ny', 'gl', 'ma'])

ax[2].boxplot([mean_thickness_bubbles_ny, mean_thickness_bubbles_gl, mean_thickness_bubbles_ma])
ax[2].set_title('Mean thickness bubbles')
ax[2].set_xticklabels(['ny', 'gl', 'ma'])

ax[3].boxplot([max_thickness_stone_ny, max_thickness_stone_gl, max_thickness_stone_ma])
ax[3].set_title('Max thickness stone')
ax[3].set_xticklabels(['ny', 'gl', 'ma'])

ax[4].boxplot([max_thickness_bubbles_ny, max_thickness_bubbles_gl, max_thickness_bubbles_ma])
ax[4].set_title('Max thickness bubbles')
ax[4].set_xticklabels(['ny', 'gl', 'ma'])

ax[5].boxplot([var_thickness_stone_ny, var_thickness_stone_gl, var_thickness_stone_ma])
ax[5].set_title('Variance thickness stone')
ax[5].set_xticklabels(['ny', 'gl', 'ma'])

ax[6].boxplot([var_thickness_bubbles_ny, var_thickness_bubbles_gl, var_thickness_bubbles_ma])
ax[6].set_title('Variance thickness bubbles')
ax[6].set_xticklabels(['ny', 'gl', 'ma'])

ax[7].boxplot([median_thickness_stone_ny, median_thickness_stone_gl, median_thickness_stone_ma])
ax[7].set_title('Median thickness stone')
ax[7].set_xticklabels(['ny', 'gl', 'ma'])

ax[8].boxplot([median_thickness_bubbles_ny, median_thickness_bubbles_gl, median_thickness_bubbles_ma])
ax[8].set_title('Median thickness bubbles')
ax[8].set_xticklabels(['ny', 'gl', 'ma'])

plt.show()

# %%
# Visualize the statistics in scatter plots in a feature matrix

stats_ny = [ratios_ny, mean_thickness_stone_ny, mean_thickness_bubbles_ny, median_thickness_stone_ny, median_thickness_bubbles_ny, max_thickness_stone_ny, max_thickness_bubbles_ny, var_thickness_stone_ny, var_thickness_bubbles_ny]
stats_gl = [ratios_gl, mean_thickness_stone_gl, mean_thickness_bubbles_gl, median_thickness_stone_gl, median_thickness_bubbles_gl, max_thickness_stone_gl, max_thickness_bubbles_gl, var_thickness_stone_gl, var_thickness_bubbles_gl]
stats_ma = [ratios_ma, mean_thickness_stone_ma, mean_thickness_bubbles_ma, median_thickness_stone_ma, median_thickness_bubbles_ma, max_thickness_stone_ma, max_thickness_bubbles_ma, var_thickness_stone_ma, var_thickness_bubbles_ma]
labels = ['ratios', 'mean_thickness_stone', 'mean_thickness_bubbles', 'median_thickness_stone', 'median_thickness_bubbles', 'max_thickness_stone', 'max_thickness_bubbles', 'var_thickness_stone', 'var_thickness_bubbles']
fig, ax = plt.subplots(len(stats_ny), len(stats_ny), figsize=(30, 30))
for i in range(len(stats_ny)):
    for j in range(len(stats_ny)):
        ax[i, j].scatter(stats_gl[i], stats_gl[j], label='gl')
        ax[i, j].scatter(stats_ma[i], stats_ma[j], label='ma')
        ax[i, j].scatter(stats_ny[i], stats_ny[j], label='ny')
        ax[i, j].set_xlabel(labels[i])
        ax[i, j].set_ylabel(labels[j])
plt.legend()
plt.show()

# %%
# Save the statistics in a dataframe
df_ny = pd.DataFrame(statistics_ny)
df_gl = pd.DataFrame(statistics_gl)
df_ma = pd.DataFrame(statistics_ma)

# add a label column to each dataframe
df_ny['label'] = 'ny'
df_gl['label'] = 'gl'
df_ma['label'] = 'ma'

# Concatenate the dataframes
df = pd.concat([df_ny, df_gl, df_ma])

# save the dataframe
df.to_csv('/dtu/3d-imaging-center/courses/02509/groups/group01/statistics_sample_' + str(sample_size) + ".csv" , index=False)
